# %%
from hwr.app.app import main

# %%
# cannot predict 'd' and 't' very well for some reason
main()
# Out:
# preloading model weights from /home/jasper/Desktop/fyp/HWR/hwr/../models/iamon/ONNET/pretrained-large-lstm/weights.h5
# <PointSet w=None h=None points_len=87>
# ...
# 100%|██████████| 1/1 [00:00<00:00,  5.03it/s]
# ['Test ', ' Test ', 'est ', '"Test ', '-Test ']
# <PointSet w=None h=None points_len=230>
# ...
# 100%|██████████| 1/1 [00:00<00:00,  1.87it/s]
# ['will tis wark day ? ', 'will his wark day ? ', 'will this wark day ? ', 'will lis wark day ? ', 'hill tis wark day ? ']
# <PointSet w=None h=None points_len=75>
# ...
# 100%|██████████| 1/1 [00:00<00:00,  6.16it/s]
# ['kay . ', 'day . ', 'clay . ', 'day ', 'key . ']
# <PointSet w=None h=None points_len=201>
# ...
# 100%|██████████| 1/1 [00:00<00:00,  2.27it/s]
# ["this is mo good ' ", "this is no good ' ", "this is mo good' ", "this is me good ' ", "this is no good' "]
# <PointSet w=None h=None points_len=99>
# ...
# 100%|██████████| 1/1 [00:00<00:00,  4.36it/s]
# ['this ! . ', 'this ! ', 'this . . ', 'this . ', 'this ? . ']
# ...
