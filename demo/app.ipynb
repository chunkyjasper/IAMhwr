# %%
from hwr.app.app import main
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0917 08:37:01.054516 140002115213056 deprecation_wrapper.py:119] From /home/jasper/Desktop/fyp/HWR/hwr/models/ONNET.py:1: The name tf.keras.layers.CuDNNGRU is deprecated. Please use tf.compat.v1.keras.layers.CuDNNGRU instead.

# %%
# cannot predict 'd' and 't' very well for some reason
main()
# Out:
# W0917 08:37:02.483230 140002115213056 deprecation.py:323] From /home/jasper/anaconda3/envs/tf_gpu2/lib/python3.7/site-packages/tensorflow/python/ops/array_ops.py:1354: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# preloading model weights from /home/jasper/Desktop/fyp/HWR/hwr/../models/iamon/ONNET/pretrained/weights.h5
# <PointSet w=None h=None points_len=208>
# ...
# 100%|██████████| 1/1 [00:01<00:00,  1.87s/it]
# ['hello there - . ', 'hello there . . . ', 'hello there - . . ', 'hello there - - ', 'hello there . . ']
